# %% [markdown]
# ## Process for fuzzy matching company names
# * This workflow is a first pass of drafting a mapping file of company names between 2 different data sources.
#
# **What makes this process particularly challenging?**
# * Company names across different sources may use different naming conventions and/or abbreviations
# * User inputted company names may contain typos that result in variations for the same company
#
# **Data Sources:**
# For this demo, we are going to use an [SEC provided list](https://www.sec.gov/rules/other/4-460list.htm) of companies and try to find matches in a sample of manually entered companies

# %%
import jellyfish
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords
import string
import re

# %% [markdown]
# * **Get SEC data fom sec.gov**
# * **Create list of user inputted names**

# %%
sec_names = pd.read_html('https://www.sec.gov/rules/other/4-460list.htm')[0].iloc[1:,[1]]

companies = ['JP Morgan Chase', 'JPM', 'JP Morgan', 'Barnes & Noble, Inc.',
             'B&N', 'Barnes and Noble, Incorporation', 'Barnes and Nobles',
            'The Black & Decker Corporation', 'Black and Decker Corp', 'Delta Air Lines Inc.',
             'Delta Airlines', 'Delta Airlines Incorporation', 'Delta', 'H&R Block',
             'Marriott International Inc.', 'Marriott Intl.', 'Marriott International Incorporation',
             '3M', 'abercombie and fitch']

user_names = pd.DataFrame(companies)

# %% [markdown]
# **Check what Jellyfish Metaphone looks like**

# %%
for company in companies[0:1]:
    print(jellyfish.metaphone(company))
# Out:
# JP MRKN XS

# %% [markdown]
# **Create empty dataframes for SEC, User Inputted, First Matching, Second Matching**

# %%
sec_df = pd.DataFrame(columns=['SEC Name', 'Acronym', 'Phonetic Representation'])
user_df = pd.DataFrame(columns=['Original User Name','User Inputed Name', 'Acronym', 'Phonetic Representation'])
matches_df = pd.DataFrame(columns=['Phonetic Representation', 'Phonetic Match Score'])
matches_df_two = pd.DataFrame(columns=['Acronym', 'Acronym Match Score'])

# %% [markdown]
# **Create list of the stopwords from NLTK and add our own**

# %%
stop = stopwords.words('english') + list(string.punctuation)

#we can't just remove common words in our list of company names because some words like 'American' repeat many times
new_words= ('inc','lp', 'llc', 'plc', 'limited', 'corporation', 'corp' ,'ltd', 'co',
            'Corporation', 'Inc', 'L.P.', 'LP', 'INC', 'LLC', 'Limited', 'Company',
            'Ltd', 'BV', 'bv', 'I', 'III', 'IV', 'V', 'VI', 'VII', 'VIII', 'X', 'L.P.',
            'Lp', 'Co', 'CO', 'PARTNERS', 'Partners', 'Incorporated', 'incorporated', 'Corp',
            'Co.', "'", 'And', 'and', '&', 'The', 'the', 'Incorporation'
          )

for i in new_words:
    stop.append(i)

# %% [markdown]
# **Clean SEC Names and User Inputted Names**
#    * Remove stopwords
#    * Create Abbreviation, if length of Acronym is greater than 1
#    * Create phonetic pronunciation from name

# %%
for row in sec_names.index:
    company = (sec_names[1][row])
    company = [i for i in word_tokenize(company) if i not in stop]
    company = " ".join(company)
    #print(company)
    company_abr = (''.join([c for c in company if c.isupper()]))
    if len(company_abr) > 1:
        company_abr = company_abr
    else:
        company_abr = ''
    company_phonetic = (jellyfish.metaphone(company))
    sec_df.loc[len(sec_df)]=[company,company_abr,company_phonetic]

# %%
for row in user_names.index:
    company = (user_names[0][row])
    company = [i for i in word_tokenize(company) if i not in stop]
    company = " ".join(company)
    company_abr = (''.join([c for c in company if c.isupper()]))
    if len(company_abr) > 1:
        company_abr = company_abr
    else:
        company_abr = ''
    company_phonetic = (jellyfish.metaphone(company))
    originalname = (user_names[0][row])
    user_df.loc[len(user_df)]=[originalname, company,company_abr,company_phonetic]

# %% [markdown]
# <b>Review at SEC Names</b>

# %%
sec_df.head()
# Out:
#               SEC Name Acronym Phonetic Representation
# 0                 3Com                              KM
# 1                   3M                               M
# 2         A.G. Edwards     AGE               AK ETWRTS
# 3  Abbott Laboratories      AL              ABT LBRTRS
# 4    Abercrombie Fitch      AF              ABRKRMB FX

# %% [markdown]
# <b>Review at User Inputted Names</b>

# %%
user_df.head()
# Out:
#      Original User Name User Inputed Name Acronym Phonetic Representation
# 0       JP Morgan Chase   JP Morgan Chase    JPMC              JP MRKN XS
# 1                   JPM               JPM     JPM                     JPM
# 2             JP Morgan         JP Morgan     JPM                 JP MRKN
# 3  Barnes & Noble, Inc.      Barnes Noble      BN                BRNS NBL
# 4                   B&N               B N      BN                     B N

# %% [markdown]
# <b>Find nearest match to phonetic representation of User Inputted Name to SEC Names List</b>

# %%
def fuzzy_merge(df_1, df_2, key1, key2, threshold=90, limit=1):
    s = df_2[key2].tolist()
    m_series = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))  
    for list_ in m_series:
        phonetic_match = [str((listItem[0])) for listItem in list_]
        score = [((listItem[1])) for listItem in list_]
        matches_df.loc[len(matches_df)]=[phonetic_match,score] 
    df_1 = pd.merge(df_1, matches_df, left_index=True, right_index=True)
    df_1['Phonetic Match Score'] = df_1['Phonetic Match Score'].str[0]
    df_1['Phonetic Representation_y'] = df_1['Phonetic Representation_y'].str[0]
    return df_1

fuzzymerge = fuzzy_merge(user_df, sec_df, 'Phonetic Representation', 'Phonetic Representation', threshold=92)

# %% [markdown]
# **Join Phonetic Match from fuzzy merge and see what the results look like**

# %%
join = pd.merge(fuzzymerge, sec_df, left_on=  ['Phonetic Representation_y'],
                   right_on= ['Phonetic Representation'], 
                   how = 'left')

join = join.drop(columns=['Acronym_y', 'Phonetic Representation'])
join = join.rename(columns = {'SEC Name':'Phonetic SEC Name'})
display(join)
# Out:
#                       Original User Name       User Inputed Name Acronym_x  \
# 0                        JP Morgan Chase         JP Morgan Chase      JPMC
# 1                                    JPM                     JPM       JPM
# 2                              JP Morgan               JP Morgan       JPM
# 3                   Barnes & Noble, Inc.            Barnes Noble        BN
# 4                                    B&N                     B N        BN
# 5        Barnes and Noble, Incorporation            Barnes Noble        BN
# 6                      Barnes and Nobles           Barnes Nobles        BN
# 7         The Black & Decker Corporation            Black Decker        BD
# 8                  Black and Decker Corp            Black Decker        BD
# 9                   Delta Air Lines Inc.         Delta Air Lines       DAL
# 10                        Delta Airlines          Delta Airlines        DA
# 11          Delta Airlines Incorporation          Delta Airlines        DA
# 12                                 Delta                   Delta
# 13                             H&R Block               H R Block       HRB
# 14           Marriott International Inc.  Marriott International        MI
# 15                        Marriott Intl.           Marriott Intl        MI
# 16  Marriott International Incorporation  Marriott International        MI
# 17                                    3M                      3M
# 18                  abercombie and fitch        abercombie fitch
#
#    Phonetic Representation_x Phonetic Representation_y  Phonetic Match Score  \
# 0                 JP MRKN XS                JP MRKN XS                   100
# 1                        JPM                         M                    90
# 2                    JP MRKN                JP MRKN XS                    95
# 3                   BRNS NBL                  BRNS NBL                   100
# 4                        B N                 BNK N YRK                    86
# 5                   BRNS NBL                  BRNS NBL                   100
# 6                  BRNS NBLS                  BRNS NBL                    94
# 7                    BLK TKR                   BLK TKR                   100
# 8                    BLK TKR                   BLK TKR                   100
# 9                 TLT AR LNS                TLT AR LNS                   100
# 10                 TLT ARLNS                TLT AR LNS                    95
# 11                 TLT ARLNS                TLT AR LNS                    95
# 12                       TLT                TLT AR LNS                    90
# 13                   H R BLK                   H R BLK                   100
# 14              MRT INTRNXNL              MRT INTRNXNL                   100
# 15                  MRT INTL                         M                    90
# 16              MRT INTRNXNL              MRT INTRNXNL                   100
# 17                         M                         M                   100
# 18                 ABRKMB FX                ABRKRMB FX                    95
#
#          Phonetic SEC Name
# 0        J.P. Morgan Chase
# 1                       3M
# 2        J.P. Morgan Chase
# 3             Barnes Noble
# 4            Bank New York
# 5             Barnes Noble
# 6             Barnes Noble
# 7             Black Decker
# 8             Black Decker
# 9          Delta Air Lines
# 10         Delta Air Lines
# 11         Delta Air Lines
# 12         Delta Air Lines
# 13               H R Block
# 14  Marriott International
# 15                      3M
# 16  Marriott International
# 17                      3M
# 18       Abercrombie Fitch

# %% [markdown]
# <b>Find nearest match on Acronym representation of User Inputted Name to SEC Names List</b>

# %%
def fuzzy_merge_two(df_1, df_2, key1, key2, threshold=90, limit=1):
    s = df_2[key2].tolist()
    m_series = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))  
    for list_ in m_series:
        phonetic_match = [str((listItem[0])) for listItem in list_]
        score = [((listItem[1])) for listItem in list_]
        matches_df_two.loc[len(matches_df_two)]=[phonetic_match,score] 
    df_1 = pd.merge(df_1, matches_df_two, left_index=True, right_index=True)
    df_1['Acronym Match Score'] = df_1['Acronym Match Score'].str[0]
    df_1['Acronym'] = df_1['Acronym'].str[0]
    return df_1

fuzzymergeTwo = fuzzy_merge_two(join, sec_df, 'Acronym_x', 'Acronym', threshold=92)
fuzzymergeTwo = fuzzymergeTwo[['Acronym','Acronym Match Score']]
fuzzymergeTwo.columns = ['SEC Acronym', 'Acronym Match Score']
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']

# %% [markdown]
# <b>Join acronym matches if acronym exists</b>
#    * Return a list of the SEC Names for the matching Acronym because there is a one to many relationship for Acronyms to SEC Names\
#      * Each SEC Name only has 1 Acronym, but 1 Acronym can have many SEC Names

# %%
finaldf = join.join(fuzzymergeTwo, lsuffix='_left')
acronym_map = pd.DataFrame(columns=['Acronym', 'Company Names'])
    
for i, row in finaldf.iterrows():
    ac = (row['SEC Acronym'])
    names = []
    if ac == '':
        names is None
    else:
        for index, row in sec_df.iterrows():
            if ac == (row['Acronym']):
                names.append((row['SEC Name']))
    names = ', '.join(names)
    acronym_map.loc[len(acronym_map)]=[ac,names]    

    joinFinal = pd.merge(finaldf, acronym_map, left_on=  ['SEC Acronym'],
                   right_on= ['Acronym'], 
                   how = 'left')

joinFinal = joinFinal.drop_duplicates()
joinFinal = joinFinal.reset_index(drop=True)

# %% [markdown]
# **Final Cleaning / Rules for Success vs. Exception and display output**
#    * Note that the final SEC name returned is a cleaned version of the actual SEC Name. We can join back to our original SEC Names dataset to get the original name back, if necessary.

# %%
joinFinal
joinFinal = joinFinal.rename(columns={'Original User Name':'Original Company Name', 
                                      'User Inputed Name':'Clean Original Name',
                                      'Acronym_x':'Clean Original Name Acronym',
                                      'Phonetic Representation_x':'Original Phonetic Representation', 
                                      'Phonetic Representation_y':'SEC Phonetic Representation',
                                      'Acronym_x':'Clean Original Name Acronym',
                                      'Acronym':'SEC Acronym',
                                      'Company Names':'Acronym SEC Names'})
joinFinal
# Out:
#                    Original Company Name     Clean Original Name  \
# 0                        JP Morgan Chase         JP Morgan Chase
# 1                                    JPM                     JPM
# 2                              JP Morgan               JP Morgan
# 3                   Barnes & Noble, Inc.            Barnes Noble
# 4                                    B&N                     B N
# 5        Barnes and Noble, Incorporation            Barnes Noble
# 6                      Barnes and Nobles           Barnes Nobles
# 7         The Black & Decker Corporation            Black Decker
# 8                  Black and Decker Corp            Black Decker
# 9                   Delta Air Lines Inc.         Delta Air Lines
# 10                        Delta Airlines          Delta Airlines
# 11          Delta Airlines Incorporation          Delta Airlines
# 12                                 Delta                   Delta
# 13                             H&R Block               H R Block
# 14           Marriott International Inc.  Marriott International
# 15                        Marriott Intl.           Marriott Intl
# 16  Marriott International Incorporation  Marriott International
# 17                                    3M                      3M
# 18                  abercombie and fitch        abercombie fitch
#
#    Clean Original Name Acronym Original Phonetic Representation  \
# 0                         JPMC                       JP MRKN XS
# 1                          JPM                              JPM
# 2                          JPM                          JP MRKN
# 3                           BN                         BRNS NBL
# 4                           BN                              B N
# 5                           BN                         BRNS NBL
# 6                           BN                        BRNS NBLS
# 7                           BD                          BLK TKR
# 8                           BD                          BLK TKR
# 9                          DAL                       TLT AR LNS
# 10                          DA                        TLT ARLNS
# 11                          DA                        TLT ARLNS
# 12                                                          TLT
# 13                         HRB                          H R BLK
# 14                          MI                     MRT INTRNXNL
# 15                          MI                         MRT INTL
# 16                          MI                     MRT INTRNXNL
# 17                                                            M
# 18                                                    ABRKMB FX
#
#    SEC Phonetic Representation  Phonetic Match Score       Phonetic SEC Name  \
# 0                   JP MRKN XS                   100       J.P. Morgan Chase
# 1                            M                    90                      3M
# 2                   JP MRKN XS                    95       J.P. Morgan Chase
# 3                     BRNS NBL                   100            Barnes Noble
# 4                    BNK N YRK                    86           Bank New York
# 5                     BRNS NBL                   100            Barnes Noble
# 6                     BRNS NBL                    94            Barnes Noble
# 7                      BLK TKR                   100            Black Decker
# 8                      BLK TKR                   100            Black Decker
# 9                   TLT AR LNS                   100         Delta Air Lines
# 10                  TLT AR LNS                    95         Delta Air Lines
# 11                  TLT AR LNS                    95         Delta Air Lines
# 12                  TLT AR LNS                    90         Delta Air Lines
# 13                     H R BLK                   100               H R Block
# 14                MRT INTRNXNL                   100  Marriott International
# 15                           M                    90                      3M
# 16                MRT INTRNXNL                   100  Marriott International
# 17                           M                   100                      3M
# 18                  ABRKRMB FX                    95       Abercrombie Fitch
#
#    SEC Acronym  Acronym Match Score SEC Acronym  \
# 0         JPMC                  100        JPMC
# 1           JP                   90          JP
# 2           JP                   90          JP
# 3           BN                  100          BN
# 4           BN                  100          BN
# 5           BN                  100          BN
# 6           BN                  100          BN
# 7           BD                  100          BD
# 8           BD                  100          BD
# 9          DAL                  100         DAL
# 10         DAL                   90         DAL
# 11         DAL                   90         DAL
# 12                                0
# 13         HRB                  100         HRB
# 14          MI                  100          MI
# 15          MI                  100          MI
# 16          MI                  100          MI
# 17                                0
# 18                                0
#
#                                     Acronym SEC Names
# 0                                   J.P. Morgan Chase
# 1                                     Jefferson-Pilot
# 2                                     Jefferson-Pilot
# 3                                        Barnes Noble
# 4                                        Barnes Noble
# 5                                        Barnes Noble
# 6                                        Barnes Noble
# 7                      Becton Dickinson, Black Decker
# 8                      Becton Dickinson, Black Decker
# 9                                     Delta Air Lines
# 10                                    Delta Air Lines
# 11                                    Delta Air Lines
# 12
# 13                                          H R Block
# 14  Marriott International, Marshall Ilsley, Mohaw...
# 15  Marriott International, Marshall Ilsley, Mohaw...
# 16  Marriott International, Marshall Ilsley, Mohaw...
# 17
# 18

# %% [markdown]
# **If the Original Phonetic Representation is found in the SEC Phonetic Representation, add a flag to pass it as a success.**
#    * We can do this because many names are shortened when users write them in

# %%
joinFinal["Phonetic Flag"] = ''

for i, row in joinFinal.iterrows():
    original_phonetic = (row['Original Phonetic Representation'])
    sec_phonetic = (row['SEC Phonetic Representation'])
    if original_phonetic in sec_phonetic:
        flag = 'X'
    else:
        flag = ''
    joinFinal.at[i,["Phonetic Flag"]] = flag

# %% [markdown]
# **Final rules for passing a fuzzy match as a success or failure**
#
# The following create a successful fuzzy match:
#    * If the User Inputted Name phonetic sound is found within the SEC Phonetic Sound
#    * If the Phonetic Match score is above 94 and the Original Name Phonetic Sound has more than 1 letter
#    * If the Acronym Match score is greater than 95

# %%
def label(row):
    if row['Phonetic Flag'] == 'X':
        return row['Phonetic SEC Name']
    elif row['Phonetic Match Score'] > 94 and len(row['Original Phonetic Representation']) > 1:
        return row['Phonetic SEC Name']
    elif row['Acronym Match Score'] > 95:
        return row['Acronym SEC Names']
    else:
        return ''
joinFinal['SEC Name'] = joinFinal.apply (lambda row: label(row), axis=1)

# %%
joinFinal
# Out:
#                    Original Company Name     Clean Original Name  \
# 0                        JP Morgan Chase         JP Morgan Chase
# 1                                    JPM                     JPM
# 2                              JP Morgan               JP Morgan
# 3                   Barnes & Noble, Inc.            Barnes Noble
# 4                                    B&N                     B N
# 5        Barnes and Noble, Incorporation            Barnes Noble
# 6                      Barnes and Nobles           Barnes Nobles
# 7         The Black & Decker Corporation            Black Decker
# 8                  Black and Decker Corp            Black Decker
# 9                   Delta Air Lines Inc.         Delta Air Lines
# 10                        Delta Airlines          Delta Airlines
# 11          Delta Airlines Incorporation          Delta Airlines
# 12                                 Delta                   Delta
# 13                             H&R Block               H R Block
# 14           Marriott International Inc.  Marriott International
# 15                        Marriott Intl.           Marriott Intl
# 16  Marriott International Incorporation  Marriott International
# 17                                    3M                      3M
# 18                  abercombie and fitch        abercombie fitch
#
#    Clean Original Name Acronym Original Phonetic Representation  \
# 0                         JPMC                       JP MRKN XS
# 1                          JPM                              JPM
# 2                          JPM                          JP MRKN
# 3                           BN                         BRNS NBL
# 4                           BN                              B N
# 5                           BN                         BRNS NBL
# 6                           BN                        BRNS NBLS
# 7                           BD                          BLK TKR
# 8                           BD                          BLK TKR
# 9                          DAL                       TLT AR LNS
# 10                          DA                        TLT ARLNS
# 11                          DA                        TLT ARLNS
# 12                                                          TLT
# 13                         HRB                          H R BLK
# 14                          MI                     MRT INTRNXNL
# 15                          MI                         MRT INTL
# 16                          MI                     MRT INTRNXNL
# 17                                                            M
# 18                                                    ABRKMB FX
#
#    SEC Phonetic Representation  Phonetic Match Score       Phonetic SEC Name  \
# 0                   JP MRKN XS                   100       J.P. Morgan Chase
# 1                            M                    90                      3M
# 2                   JP MRKN XS                    95       J.P. Morgan Chase
# 3                     BRNS NBL                   100            Barnes Noble
# 4                    BNK N YRK                    86           Bank New York
# 5                     BRNS NBL                   100            Barnes Noble
# 6                     BRNS NBL                    94            Barnes Noble
# 7                      BLK TKR                   100            Black Decker
# 8                      BLK TKR                   100            Black Decker
# 9                   TLT AR LNS                   100         Delta Air Lines
# 10                  TLT AR LNS                    95         Delta Air Lines
# 11                  TLT AR LNS                    95         Delta Air Lines
# 12                  TLT AR LNS                    90         Delta Air Lines
# 13                     H R BLK                   100               H R Block
# 14                MRT INTRNXNL                   100  Marriott International
# 15                           M                    90                      3M
# 16                MRT INTRNXNL                   100  Marriott International
# 17                           M                   100                      3M
# 18                  ABRKRMB FX                    95       Abercrombie Fitch
#
#    SEC Acronym  Acronym Match Score SEC Acronym  \
# 0         JPMC                  100        JPMC
# 1           JP                   90          JP
# 2           JP                   90          JP
# 3           BN                  100          BN
# 4           BN                  100          BN
# 5           BN                  100          BN
# 6           BN                  100          BN
# 7           BD                  100          BD
# 8           BD                  100          BD
# 9          DAL                  100         DAL
# 10         DAL                   90         DAL
# 11         DAL                   90         DAL
# 12                                0
# 13         HRB                  100         HRB
# 14          MI                  100          MI
# 15          MI                  100          MI
# 16          MI                  100          MI
# 17                                0
# 18                                0
#
#                                     Acronym SEC Names Phonetic Flag  \
# 0                                   J.P. Morgan Chase             X
# 1                                     Jefferson-Pilot
# 2                                     Jefferson-Pilot             X
# 3                                        Barnes Noble             X
# 4                                        Barnes Noble
# 5                                        Barnes Noble             X
# 6                                        Barnes Noble
# 7                      Becton Dickinson, Black Decker             X
# 8                      Becton Dickinson, Black Decker             X
# 9                                     Delta Air Lines             X
# 10                                    Delta Air Lines
# 11                                    Delta Air Lines
# 12                                                                X
# 13                                          H R Block             X
# 14  Marriott International, Marshall Ilsley, Mohaw...             X
# 15  Marriott International, Marshall Ilsley, Mohaw...
# 16  Marriott International, Marshall Ilsley, Mohaw...             X
# 17                                                                X
# 18
#
#                                              SEC Name
# 0                                   J.P. Morgan Chase
# 1
# 2                                   J.P. Morgan Chase
# 3                                        Barnes Noble
# 4                                        Barnes Noble
# 5                                        Barnes Noble
# 6                                        Barnes Noble
# 7                                        Black Decker
# 8                                        Black Decker
# 9                                     Delta Air Lines
# 10                                    Delta Air Lines
# 11                                    Delta Air Lines
# 12                                    Delta Air Lines
# 13                                          H R Block
# 14                             Marriott International
# 15  Marriott International, Marshall Ilsley, Mohaw...
# 16                             Marriott International
# 17                                                 3M
# 18                                  Abercrombie Fitch

# %% [markdown]
# **If a match, send to matches dataframe. If no match, send to excetion list**

# %%
matches = joinFinal[joinFinal['SEC Name'] != '']
exceptionList = joinFinal[joinFinal['SEC Name'] == '']

# %%
exceptionList
# Out:
#   Original Company Name Clean Original Name Clean Original Name Acronym  \
# 1                   JPM                 JPM                         JPM
#
#   Original Phonetic Representation SEC Phonetic Representation  \
# 1                              JPM                           M
#
#    Phonetic Match Score Phonetic SEC Name SEC Acronym  Acronym Match Score  \
# 1                    90                3M          JP                   90
#
#   SEC Acronym Acronym SEC Names Phonetic Flag SEC Name
# 1          JP   Jefferson-Pilot

# %%
matches
# Out:
#                    Original Company Name     Clean Original Name  \
# 0                        JP Morgan Chase         JP Morgan Chase
# 2                              JP Morgan               JP Morgan
# 3                   Barnes & Noble, Inc.            Barnes Noble
# 4                                    B&N                     B N
# 5        Barnes and Noble, Incorporation            Barnes Noble
# 6                      Barnes and Nobles           Barnes Nobles
# 7         The Black & Decker Corporation            Black Decker
# 8                  Black and Decker Corp            Black Decker
# 9                   Delta Air Lines Inc.         Delta Air Lines
# 10                        Delta Airlines          Delta Airlines
# 11          Delta Airlines Incorporation          Delta Airlines
# 12                                 Delta                   Delta
# 13                             H&R Block               H R Block
# 14           Marriott International Inc.  Marriott International
# 15                        Marriott Intl.           Marriott Intl
# 16  Marriott International Incorporation  Marriott International
# 17                                    3M                      3M
# 18                  abercombie and fitch        abercombie fitch
#
#    Clean Original Name Acronym Original Phonetic Representation  \
# 0                         JPMC                       JP MRKN XS
# 2                          JPM                          JP MRKN
# 3                           BN                         BRNS NBL
# 4                           BN                              B N
# 5                           BN                         BRNS NBL
# 6                           BN                        BRNS NBLS
# 7                           BD                          BLK TKR
# 8                           BD                          BLK TKR
# 9                          DAL                       TLT AR LNS
# 10                          DA                        TLT ARLNS
# 11                          DA                        TLT ARLNS
# 12                                                          TLT
# 13                         HRB                          H R BLK
# 14                          MI                     MRT INTRNXNL
# 15                          MI                         MRT INTL
# 16                          MI                     MRT INTRNXNL
# 17                                                            M
# 18                                                    ABRKMB FX
#
#    SEC Phonetic Representation  Phonetic Match Score       Phonetic SEC Name  \
# 0                   JP MRKN XS                   100       J.P. Morgan Chase
# 2                   JP MRKN XS                    95       J.P. Morgan Chase
# 3                     BRNS NBL                   100            Barnes Noble
# 4                    BNK N YRK                    86           Bank New York
# 5                     BRNS NBL                   100            Barnes Noble
# 6                     BRNS NBL                    94            Barnes Noble
# 7                      BLK TKR                   100            Black Decker
# 8                      BLK TKR                   100            Black Decker
# 9                   TLT AR LNS                   100         Delta Air Lines
# 10                  TLT AR LNS                    95         Delta Air Lines
# 11                  TLT AR LNS                    95         Delta Air Lines
# 12                  TLT AR LNS                    90         Delta Air Lines
# 13                     H R BLK                   100               H R Block
# 14                MRT INTRNXNL                   100  Marriott International
# 15                           M                    90                      3M
# 16                MRT INTRNXNL                   100  Marriott International
# 17                           M                   100                      3M
# 18                  ABRKRMB FX                    95       Abercrombie Fitch
#
#    SEC Acronym  Acronym Match Score SEC Acronym  \
# 0         JPMC                  100        JPMC
# 2           JP                   90          JP
# 3           BN                  100          BN
# 4           BN                  100          BN
# 5           BN                  100          BN
# 6           BN                  100          BN
# 7           BD                  100          BD
# 8           BD                  100          BD
# 9          DAL                  100         DAL
# 10         DAL                   90         DAL
# 11         DAL                   90         DAL
# 12                                0
# 13         HRB                  100         HRB
# 14          MI                  100          MI
# 15          MI                  100          MI
# 16          MI                  100          MI
# 17                                0
# 18                                0
#
#                                     Acronym SEC Names Phonetic Flag  \
# 0                                   J.P. Morgan Chase             X
# 2                                     Jefferson-Pilot             X
# 3                                        Barnes Noble             X
# 4                                        Barnes Noble
# 5                                        Barnes Noble             X
# 6                                        Barnes Noble
# 7                      Becton Dickinson, Black Decker             X
# 8                      Becton Dickinson, Black Decker             X
# 9                                     Delta Air Lines             X
# 10                                    Delta Air Lines
# 11                                    Delta Air Lines
# 12                                                                X
# 13                                          H R Block             X
# 14  Marriott International, Marshall Ilsley, Mohaw...             X
# 15  Marriott International, Marshall Ilsley, Mohaw...
# 16  Marriott International, Marshall Ilsley, Mohaw...             X
# 17                                                                X
# 18
#
#                                              SEC Name
# 0                                   J.P. Morgan Chase
# 2                                   J.P. Morgan Chase
# 3                                        Barnes Noble
# 4                                        Barnes Noble
# 5                                        Barnes Noble
# 6                                        Barnes Noble
# 7                                        Black Decker
# 8                                        Black Decker
# 9                                     Delta Air Lines
# 10                                    Delta Air Lines
# 11                                    Delta Air Lines
# 12                                    Delta Air Lines
# 13                                          H R Block
# 14                             Marriott International
# 15  Marriott International, Marshall Ilsley, Mohaw...
# 16                             Marriott International
# 17                                                 3M
# 18                                  Abercrombie Fitch

# %% [markdown]
# **View the final matches with just Original Name and SEC Name (clean)**

# %%
matches_no_details = matches[['Original Company Name', 'SEC Name']]
matches_no_details
# Out:
#                    Original Company Name  \
# 0                        JP Morgan Chase
# 2                              JP Morgan
# 3                   Barnes & Noble, Inc.
# 4                                    B&N
# 5        Barnes and Noble, Incorporation
# 6                      Barnes and Nobles
# 7         The Black & Decker Corporation
# 8                  Black and Decker Corp
# 9                   Delta Air Lines Inc.
# 10                        Delta Airlines
# 11          Delta Airlines Incorporation
# 12                                 Delta
# 13                             H&R Block
# 14           Marriott International Inc.
# 15                        Marriott Intl.
# 16  Marriott International Incorporation
# 17                                    3M
# 18                  abercombie and fitch
#
#                                              SEC Name
# 0                                   J.P. Morgan Chase
# 2                                   J.P. Morgan Chase
# 3                                        Barnes Noble
# 4                                        Barnes Noble
# 5                                        Barnes Noble
# 6                                        Barnes Noble
# 7                                        Black Decker
# 8                                        Black Decker
# 9                                     Delta Air Lines
# 10                                    Delta Air Lines
# 11                                    Delta Air Lines
# 12                                    Delta Air Lines
# 13                                          H R Block
# 14                             Marriott International
# 15  Marriott International, Marshall Ilsley, Mohaw...
# 16                             Marriott International
# 17                                                 3M
# 18                                  Abercrombie Fitch
